# %%
import pandas as pd

# %%
df = pd.read_csv("list.csv")
df= df[df['imdb_rate'].notna()]
df
# Out:
#       Unnamed: 0                             name                url  \
# 0             15            Убийцы цветочной луны  /title/tt5537002/
# 1             58                Побег из Шоушенка  /title/tt0111161/
# 2             48                    Крестный отец  /title/tt0068646/
# 3              0  Человек-паук: Паутина вселенных  /title/tt9362722/
# 4            193                  Список Шиндлера  /title/tt0108052/
# ...          ...                              ...                ...
# 4339        1515        Драконий жемчуг: Эволюция  /title/tt1098327/
# 4340        3659                Поле битвы: Земля  /title/tt0185183/
# 4341        2986             Очень эпическое кино  /title/tt0799949/
# 4342        4120                        Сын маски  /title/tt0362165/
# 4343        2898            Нереальный блокбастер  /title/tt1213644/
#
#      global_rate release_year imdb_rate  metascore_rate  \
# 0            16.       (2023)       9,4            91.0
# ...
